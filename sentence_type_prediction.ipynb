# %% [markdown]
# # 환경설정

# %%
# 소스코드 가져오기
# !git clone https://github.com/Artificial-Society/nia_sentence_prediction

# 폴더에 들어가 필요한 파일 설치
# %cd nia_sentence_prediction/
# !pip install -q -r requirements.txt
# Out:
# Cloning into 'nia_sentence_prediction'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 165 (delta 0), reused 0 (delta 0), pack-reused 161
# Receiving objects: 100% (165/165), 24.08 MiB | 7.73 MiB/s, done.
# Resolving deltas: 100% (70/70), done.
# /content/nia_sentence_prediction
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 25.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 49.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.5 MB/s eta 0:00:00

# %% [markdown]
# # Training_문장유형

# %%
import classifier

CLS = classifier.Classification(model_name='kykim/bert-kor-base', min_sentence_length=5, MAX_LEN=128, batch_size=32, use_bert_tokenizer=True)
CLS.dataset(data_path='data/data.tsv', col_sentence='text', col_label='label')
CLS.load_model(mode='train')
CLS.train(epochs=3, dataset_split=0.1)
# Out:
# 4 labels, 4998 dataset
# label counts:: Counter({0: 1981, 2: 1341, 1: 1295, 3: 381})
# ...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at kykim/bert-kor-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# train-dataset is prepared
#
# ======== Epoch 1 / 3 ========
# Training...
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   Batch   100  of    141.    Elapsed: 0:02:01.
#
#   Train loss: 0.62, Train Accuracy: 0.74
#   Training epcoh took: 0:02:52
#
# Running Validation...
#   Validation Accuracy: 0.80
#   Validation took: 0:00:07
# ...

# %% [markdown]
# # Training_극성

# %%
import classifier

CLS = classifier.Classification(model_name='kykim/bert-kor-base', min_sentence_length=5, MAX_LEN=128, batch_size=32, use_bert_tokenizer=True)
CLS.dataset(data_path='data/data.tsv', col_sentence='text', col_label='pol')
CLS.load_model(mode='train')
CLS.train(epochs=3, dataset_split=0.1)

# %% [markdown]
# # Training_확실성

# %%
import classifier

CLS = classifier.Classification(model_name='kykim/bert-kor-base', min_sentence_length=5, MAX_LEN=128, batch_size=32, use_bert_tokenizer=True)
CLS.dataset(data_path='data/data.tsv', col_sentence='text', col_label='cer')
CLS.load_model(mode='train')
CLS.train(epochs=3, dataset_split=0.1)
